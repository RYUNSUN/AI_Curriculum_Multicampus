# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
import sklearn.preprocessing 
from sklearn.preprocessing import StandardScaler, RobustScaler
import matplotlib.pyplot as plt

# %% [markdown]
# 1. 캐글 -> 타이타닉 -> 호칭 -> 호칭별 건수 -> 소트 -> 상위 10개 호칭 조사

# %%
titanic_data=pd.read_csv('train.csv')
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_data['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 6                                McCarthy, Mr. Timothy J
# 7                         Palsson, Master. Gosta Leonard
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 10                       Sandstrom, Miss. Marguerite Rut
# 11                              Bonnell, Miss. Elizabeth
# 12                        Saundercock, Mr. William Henry
# 13                           Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss. Hulda Amanda Adolfina
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
temp=titanic_data['Name'].str.split(',').str[1]

# %%
titanic_data['title']=temp.str.split('.').str[0]

# %%
titanic_title=titanic_data['title'].value_counts(sort=True)
titanic_title
# Out:
#  Mr              517
#  Miss            182
#  Mrs             125
#  Master           40
#  Dr                7
#  Rev               6
#  Mlle              2
#  Col               2
#  Major             2
#  Don               1
#  Jonkheer          1
#  Ms                1
#  Capt              1
#  Sir               1
#  Mme               1
#  Lady              1
#  the Countess      1
# Name: title, dtype: int64

# %% [markdown]
# 나이(age) -> 구간화 -> 구간별 건수 -> 소트 -> 건수 출력

# %%
pd.isnull(titanic_data['Age']).sum()
# Out:
# 177

# %%
titanic_data['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      NaN
# 18     31.0
# 19      NaN
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      NaN
# 27     19.0
# 28      NaN
# 29      NaN
#        ...
# 861    21.0
# 862    48.0
# 863     NaN
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
mean=np.mean(titanic_data['Age'])

# %%
titanic_data['Age']=titanic_data['Age'].fillna(np.mean(mean)).astype(int)

# %%
res=pd.cut(titanic_data['Age'], bins=[0,10,20,30,40,50,60,70])

# %%
pd.value_counts(res, sort=True)
# Out:
# (20, 30]    408
# (30, 40]    155
# (10, 20]    116
# (40, 50]     84
# (0, 10]      57
# (50, 60]     42
# (60, 70]     18
# Name: Age, dtype: int64

# %% [markdown]
# 캐글 -> 타이타닉 -> 성별 -> 0(여)/1(남) (이진화)

# %%
titanic_data['Sex']=np.where(titanic_data['Sex']=='female',0,1)
titanic_data['Sex']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f89fd2eea2af> in <module>
# ----> 1 titanic_data['Sex']=np.where(titanic_data['Sex']=='female',0,1)
#       2 titanic_data['Sex']
#
# NameError: name 'titanic_data' is not defined

# %% [markdown]
# 관심 회사 -> 주식데이터 다운로드(1개월) -> 표준화/정규화(함수 직접 구현)

# %%
s_data=pd.read_csv("samsung.csv")
s_data
# Out:
#           Date     Open     High      Low    Close  Adj Close      Volume
# 0   2019-06-04      NaN      NaN      NaN      NaN        NaN         NaN
# 1   2019-06-05  44050.0  44200.0  43700.0  43900.0    43900.0  12464135.0
# 2   2019-06-07  43600.0  44350.0  43450.0  44200.0    44200.0  11683682.0
# 3   2019-06-10  44300.0  44850.0  44050.0  44800.0    44800.0   8792182.0
# 4   2019-06-11  44800.0  45000.0  44550.0  44850.0    44850.0   6664872.0
# 5   2019-06-12  44800.0  45050.0  44300.0  44600.0    44600.0   8607439.0
# 6   2019-06-13  44200.0  44400.0  43400.0  43750.0    43750.0  16906541.0
# 7   2019-06-14  43750.0  44150.0  43300.0  44000.0    44000.0   9322873.0
# 8   2019-06-17  43750.0  44050.0  43400.0  43900.0    43900.0  11890424.0
# 9   2019-06-18  43750.0  44500.0  43650.0  44350.0    44350.0   7994928.0
# 10  2019-06-19  45450.0  45450.0  45000.0  45350.0    45350.0  10417690.0
# 11  2019-06-20  44850.0  45500.0  44850.0  45500.0    45500.0   7147785.0
# ...

# %%
s_data=s_data.iloc[1:,1:]
s_data.min(axis=0)
# Out:
# Low            43300.0
# Close          43750.0
# Adj Close      43750.0
# Volume       6085066.0
# dtype: float64

# %%
normalize=(s_data-s_data.min(axis=0))/(s_data.max(axis=0)-s_data.min(axis=0))
normalize
# Out:
#          Low     Close  Adj Close    Volume
# 3   0.220588  0.323077   0.323077  0.250161
# 4   0.367647  0.338462   0.338462  0.053579
# 5   0.294118  0.261538   0.261538  0.233090
# 6   0.029412  0.000000   0.000000  1.000000
# 7   0.000000  0.076923   0.076923  0.299202
# 8   0.029412  0.046154   0.046154  0.536466
# 9   0.102941  0.184615   0.184615  0.176488
# 10  0.500000  0.492308   0.492308  0.400373
# 11  0.455882  0.538462   0.538462  0.098205
# 12  0.558824  0.600000   0.600000  0.311404
# 13  0.558824  0.538462   0.538462  0.000000
# 14  0.558824  0.569231   0.569231  0.091643
# 15  0.676471  0.600000   0.600000  0.290259
# 16  0.720588  0.846154   0.846154  0.602364
# 17  1.000000  1.000000   1.000000  0.634310
# 18  0.867647  0.876923   0.876923  0.489624
# 19  0.750000  0.769231   0.769231  0.219749
# 20  0.558824  0.507692   0.507692  0.331221
# 21  0.573529  0.692308   0.692308  0.025921

# %%
from sklearn.preprocessing import minmax_scale

# %%
minmax_scale(s_data,axis=0)
# Out:
# array([[0.22058824, 0.32307692, 0.32307692, 0.25016146],
#        [0.36764706, 0.33846154, 0.33846154, 0.0535792 ],
#        [0.29411765, 0.26153846, 0.26153846, 0.23308957],
#        [0.02941176, 0.        , 0.        , 1.        ],
#        [0.        , 0.07692308, 0.07692308, 0.299202  ],
#        [0.02941176, 0.04615385, 0.04615385, 0.53646642],
#        [0.10294118, 0.18461538, 0.18461538, 0.17648814],
#        [0.5       , 0.49230769, 0.49230769, 0.40037278],
#        [0.45588235, 0.53846154, 0.53846154, 0.09820463],
#        [0.55882353, 0.6       , 0.6       , 0.31140367],
#        [0.55882353, 0.53846154, 0.53846154, 0.        ],
#        [0.55882353, 0.56923077, 0.56923077, 0.09164259],
#        [0.67647059, 0.6       , 0.6       , 0.29025905],
#        [0.72058824, 0.84615385, 0.84615385, 0.6023641 ],
#        [1.        , 1.        , 1.        , 0.63430956],
#        [0.86764706, 0.87692308, 0.87692308, 0.4896242 ],
# ...

# %%
from numpy import mean, std, median, percentile
std_data=(s_data-mean(s_data,axis=0))/std(s_data,axis=0)

# %%
std_data
# Out:
#         Open      High       Low     Close  Adj Close    Volume
# 1  -0.996162 -1.299482 -1.064965 -1.385823  -1.385823  1.028066
# 2  -1.428977 -1.148713 -1.317384 -1.068919  -1.068919  0.730252
# 3  -0.755709 -0.646151 -0.711580 -0.435113  -0.435113 -0.373122
# 4  -0.274803 -0.495383 -0.206743 -0.382296  -0.382296 -1.184887
# 5  -0.274803 -0.445126 -0.459161 -0.646382  -0.646382 -0.443619
# 6  -0.851890 -1.098457 -1.367868 -1.544274  -1.544274  2.723254
# 7  -1.284705 -1.349738 -1.468835 -1.280188  -1.280188 -0.170615
# 8  -1.284705 -1.450251 -1.367868 -1.385823  -1.385823  0.809143
# 9  -1.284705 -0.997945 -1.115449 -0.910468  -0.910468 -0.677348
# 10  0.350374 -0.043077  0.247610  0.145876   0.145876  0.247159
# 11 -0.226713  0.007179  0.096159  0.304328   0.304328 -1.000611
# 12  0.638918  0.308717  0.449545  0.515596   0.515596 -0.120229
# 13  0.109921  0.308717  0.449545  0.304328   0.304328 -1.406137
# 14  0.109921  0.308717  0.449545  0.409962   0.409962 -1.027709
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
std_data1=StandardScaler().fit_transform(s_data)

# %%
std_data1
# Out:
# array([[-0.99616173, -1.29948194, -1.06496539, -1.3858226 , -1.3858226 ,
#          1.02806635],
#        [-1.42897682, -1.14871332, -1.31738382, -1.06891943, -1.06891943,
#          0.73025156],
#        [-0.7557089 , -0.64615124, -0.71157958, -0.43511309, -0.43511309,
#         -0.37312232],
#        [-0.27480324, -0.49538262, -0.20674272, -0.38229589, -0.38229589,
#         -1.18488725],
#        [-0.27480324, -0.44512641, -0.45916115, -0.64638187, -0.64638187,
#         -0.44361881],
#        [-0.85189003, -1.09845711, -1.36786751, -1.54427419, -1.54427419,
#          2.72325389],
#        [-1.28470513, -1.34973815, -1.46883488, -1.28018821, -1.28018821,
#         -0.17061477],
#        [-1.28470513, -1.45025056, -1.36786751, -1.3858226 , -1.3858226 ,
#          0.8091427 ],
#        [-1.28470513, -0.99794469, -1.11544907, -0.91046784, -0.91046784,
#         -0.67734824],
#        [ 0.35037413, -0.04307675,  0.24761046,  0.14587606,  0.14587606,
#          0.24715888],
# ...

# %%
rbs_x=RobustScaler().fit_transform(s_data)

# %%
rbs_x
# Out:
# array([[-0.74193548, -0.76470588, -0.83870968, -1.11111111, -1.11111111,
#          0.85157807],
#        [-1.03225806, -0.67647059, -1.        , -0.88888889, -0.88888889,
#          0.64000175],
#        [-0.58064516, -0.38235294, -0.61290323, -0.44444444, -0.44444444,
#         -0.14386728],
#        [-0.25806452, -0.29411765, -0.29032258, -0.40740741, -0.40740741,
#         -0.72056879],
#        [-0.25806452, -0.26470588, -0.4516129 , -0.59259259, -0.59259259,
#         -0.19395004],
#        [-0.64516129, -0.64705882, -1.03225806, -1.22222222, -1.22222222,
#          2.05588879],
#        [-0.93548387, -0.79411765, -1.09677419, -1.03703704, -1.03703704,
#          0.        ],
#        [-0.93548387, -0.85294118, -1.03225806, -1.11111111, -1.11111111,
#          0.69604831],
#        [-0.93548387, -0.58823529, -0.87096774, -0.77777778, -0.77777778,
#         -0.35999825],
#        [ 0.16129032, -0.02941176,  0.        , -0.03703704, -0.03703704,
#          0.29679859],
# ...

# %%
rbs_x1=(s_data-median(s_data,axis=0)) / (percentile(s_data,75,axis=0)-percentile
                                         (s_data,25,axis=0))

# %%
rbs_x1
# Out:
#         Open      High       Low     Close  Adj Close    Volume
# 1  -0.741935 -0.764706 -0.838710 -1.111111  -1.111111  0.851578
# 2  -1.032258 -0.676471 -1.000000 -0.888889  -0.888889  0.640002
# 3  -0.580645 -0.382353 -0.612903 -0.444444  -0.444444 -0.143867
# 4  -0.258065 -0.294118 -0.290323 -0.407407  -0.407407 -0.720569
# 5  -0.258065 -0.264706 -0.451613 -0.592593  -0.592593 -0.193950
# 6  -0.645161 -0.647059 -1.032258 -1.222222  -1.222222  2.055889
# 7  -0.935484 -0.794118 -1.096774 -1.037037  -1.037037  0.000000
# 8  -0.935484 -0.852941 -1.032258 -1.111111  -1.111111  0.696048
# 9  -0.935484 -0.588235 -0.870968 -0.777778  -0.777778 -0.359998
# 10  0.161290 -0.029412  0.000000 -0.037037  -0.037037  0.296799
# 11 -0.225806  0.000000 -0.096774  0.074074   0.074074 -0.589654
# 12  0.354839  0.176471  0.129032  0.222222   0.222222  0.035795
# 13  0.000000  0.176471  0.129032  0.074074   0.074074 -0.877751
# 14  0.000000  0.176471  0.129032  0.148148   0.148148 -0.608905
# ...
